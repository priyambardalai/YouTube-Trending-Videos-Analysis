# %%
# import necessary packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load the data
data = pd.read_csv("USvideos.csv")

# %%
data.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
# check the data types of each features
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
# ...

# %%
# find the mean,average,median, std of each columns
data.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
# check for null values
data.isnull().sum()
# decription feature which is object has nan values
# Out:
# video_id                    0
# trending_date               0
# title                       0
# channel_title               0
# category_id                 0
# publish_time                0
# tags                        0
# views                       0
# likes                       0
# dislikes                    0
# comment_count               0
# thumbnail_link              0
# comments_disabled           0
# ratings_disabled            0
# video_error_or_removed      0
# description               570
# dtype: int64

# %%
data['description'].value_counts()
# Out:
# ► Listen LIVE: http://power1051fm.com/\n► Facebook: https://www.facebook.com/Power1051NY/\n► Twitter: https://twitter.com/power1051/\n► Instagram: https://www.instagram.com/power1051/                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               
# ...

# %%
# replacing categorical null values with 
data["description"] = data["description"].fillna(value="Missing")

# %%
data.isnull().sum()
# now there is no null values
# Out:
# video_id                  0
# trending_date             0
# title                     0
# channel_title             0
# category_id               0
# publish_time              0
# tags                      0
# views                     0
# likes                     0
# dislikes                  0
# comment_count             0
# thumbnail_link            0
# comments_disabled         0
# ratings_disabled          0
# video_error_or_removed    0
# description               0
# dtype: int64

# %%
 data.corr()
# Out:
#                         category_id     views     likes  dislikes  \
# category_id                1.000000 -0.168231 -0.173921 -0.033547
# views                     -0.168231  1.000000  0.849177  0.472213
# likes                     -0.173921  0.849177  1.000000  0.447186
# dislikes                  -0.033547  0.472213  0.447186  1.000000
# comment_count             -0.076307  0.617621  0.803057  0.700184
# comments_disabled          0.048949  0.002677 -0.028918 -0.004431
# ratings_disabled          -0.013506  0.015355 -0.020888 -0.008230
# video_error_or_removed    -0.030011 -0.002256 -0.002641 -0.001853
#
#                         comment_count  comments_disabled  ratings_disabled  \
# category_id                 -0.076307           0.048949         -0.013506
# views                        0.617621           0.002677          0.015355
# likes                        0.803057          -0.028918         -0.020888
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
# now for the categorical features
categorical_features = []
for feature in data.columns:
    if data[feature].dtype=='O':
        
        categorical_features.append(feature)

# %%
categorical_features
# Out:
# ['video_id',
#  'trending_date',
#  'title',
#  'channel_title',
#  'publish_time',
#  'tags',
#  'thumbnail_link',
#  'description']

# %%
# now for the numerical features
numerical_features = []
for feature in data.columns:
    if data[feature].dtype!='O':
        
        numerical_features.append(feature)

# %%
numerical_features
# Out:
# ['category_id',
#  'views',
#  'likes',
#  'dislikes',
#  'comment_count',
#  'comments_disabled',
#  'ratings_disabled',
#  'video_error_or_removed']

# %%
data["comments_disabled"].value_counts()
# Out:
# False    40316
# True       633
# Name: comments_disabled, dtype: int64

# %%
custom = {True:1,False:0}
data['comments_disabled'] = data['comments_disabled'].map(custom)

# %%
data['comments_disabled'].value_counts()
# Out:
# 0    40316
# 1      633
# Name: comments_disabled, dtype: int64

# %%
sns.countplot(data['comments_disabled'])
# Out:
# C:\Users\Priyam\Open_Pose_Project\pose\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='comments_disabled', ylabel='count'>

# %%
data['ratings_disabled'].value_counts()
# Out:
# 0    40780
# 1      169
# Name: ratings_disabled, dtype: int64

# %%
custom2 = {True:1,False:0}
data['ratings_disabled'] = data['ratings_disabled'].map(custom)

# %%
data['video_error_or_removed']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 40944    0
# 40945    0
# 40946    0
# 40947    0
# 40948    0
# Name: video_error_or_removed, Length: 40949, dtype: int64

# %%
custom3 = {True:1,False:0}
data['video_error_or_removed'] = data['video_error_or_removed'].map(custom)

# %%
# now we check their distribution of datas
for i in numerical_features:
    data_copy = data.copy()
    data_copy[i].hist(bins=25)
    plt.xlabel(i)
    plt.ylabel("Count")
    plt.title(i)
    plt.show()
    
    # here we analyzed that some features follows gaussian distributions.

# %%
data['title_length']= 0

# %%
data.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
length = []
for feature in data.title:
    length.append(len(feature))

# %%
a = data['title_length']
count = 0
for i in length:
    a[count] = length[i]
    count+=1
# Out:
# <ipython-input-92-2e440248d829>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[count] = length[i]

# %%
data['title_length'].value_counts()
# Out:
# 50     2734
# 54     2014
# 75     1858
# 48     1810
# 65     1770
# 57     1607
# 58     1470
# 60     1347
# 33     1252
# 51     1239
# 45     1109
# 38     1075
# 55     1034
# 43      965
# 42      947
# 40      938
# 46      921
# 20      778
# 31      774
# 98      767
# 47      726
# 72      707
# 39      695
# 29      690
# 71      677
# 85      672
# 17      648
# 36      647
# 23      628
# 27      621
# 100     583
# 94      502
# 26      498
# 67      487
# 34      485
# 28      465
# 32      461
# 53      413
# 68      375
# 66      367
# 76      360
# 64      336
# 56      320
# 74      313
# 61      283
# 52      269
# 30      203
# 83      182
# 44      181
# 24      162
# 80      157
# 16      152
# 59      136
# 78       57
# 86       54
# 35       20
# 41        8
# Name: title_length, dtype: int64

# %%
data.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
sns.distplot( data['title_length'])
# Out:
# C:\Users\Priyam\Open_Pose_Project\pose\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='title_length', ylabel='Density'>

# %%
# here we analysed that the title contains mostly 40 -60 characters atmost and it is following a normal dist

# %%
# now we analyse the relationship between title length and the views
plt.scatter(x = data['views'],y =  data['title_length'])
plt.xlabel("Views")
plt.ylabel('Title_Length')

# we analyzed that the views above 1.3 have title length between 40-60 characters
# Out:
# Text(0, 0.5, 'Title_Length')

# %%
h_labels = [x.replace('_', ' ').title() for x in 
            list(data.select_dtypes(include=['number', 'bool']).columns.values)]

fig, ax = plt.subplots(figsize=(10,6))
_ = sns.heatmap(data.corr(), annot=True, xticklabels=h_labels, yticklabels=h_labels, cmap=sns.cubehelix_palette(as_cmap=True), ax=ax)

# %%
import wordcloud
title_words = list(data["title"].apply(lambda x: x.split()))
title_words = [x for y in title_words for x in y]
wc = wordcloud.WordCloud(width=1200, height=500, 
                         collocations=False, background_color="white", 
                         colormap="tab20b").generate(" ".join(title_words))

plt.figure(figsize=(15,10))
plt.imshow(wc, interpolation='bilinear')
_ = plt.axis("off")
